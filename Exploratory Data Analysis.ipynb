# %% [markdown]
# # Task 05

# %% [markdown]
# # Name : Jeeva K

# %% [markdown]
# # Importing all libraries required

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Loading Data

# %%
data = pd.read_csv("matches.csv")
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data.tail()
# Out:
#         id  season           city      date                  team1  \
# 751  11347    2019         Mumbai  05/05/19  Kolkata Knight Riders
# 752  11412    2019        Chennai  07/05/19    Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08/05/19    Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10/05/19         Delhi Capitals
# 755  11415    2019      Hyderabad  12/05/19         Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 751       Mumbai Indians       Mumbai Indians         field  normal
# 752       Mumbai Indians  Chennai Super Kings           bat  normal
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
# 755  Chennai Super Kings       Mumbai Indians           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 751           0       Mumbai Indians            0               9
# ...

# %% [markdown]
# # Check the missing value

# %%
data.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
import missingno as no
no.bar(data,figsize=(10,5), fontsize=12, color=(0.27, 0.52, 1.0))
plt.title("Null Values")
plt.show()

# %% [markdown]
# # Dropping the duplicate rows

# %%
data.dropna(axis=1,inplace=True)

# %%
data.head()
# Out:
#    id  season        date                        team1  \
# 0   1    2017  2017-04-05          Sunrisers Hyderabad
# 1   2    2017  2017-04-06               Mumbai Indians
# 2   3    2017  2017-04-07                Gujarat Lions
# 3   4    2017  2017-04-08       Rising Pune Supergiant
# 4   5    2017  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied  win_by_runs  win_by_wickets  \
# 0  normal           0           35               0
# 1  normal           0            0               7
# ...

# %%
data.tail()
# Out:
#         id  season      date                  team1                team2  \
# 751  11347    2019  05/05/19  Kolkata Knight Riders       Mumbai Indians
# 752  11412    2019  07/05/19    Chennai Super Kings       Mumbai Indians
# 753  11413    2019  08/05/19    Sunrisers Hyderabad       Delhi Capitals
# 754  11414    2019  10/05/19         Delhi Capitals  Chennai Super Kings
# 755  11415    2019  12/05/19         Mumbai Indians  Chennai Super Kings
#
#              toss_winner toss_decision  result  dl_applied  win_by_runs  \
# 751       Mumbai Indians         field  normal           0            0
# 752  Chennai Super Kings           bat  normal           0            0
# 753       Delhi Capitals         field  normal           0            0
# 754  Chennai Super Kings         field  normal           0            0
# 755       Mumbai Indians           bat  normal           0            1
#
#      win_by_wickets                               venue
# ...

# %%
data.isnull().sum()
# Out:
# id                0
# season            0
# date              0
# team1             0
# team2             0
# toss_winner       0
# toss_decision     0
# result            0
# dl_applied        0
# win_by_runs       0
# win_by_wickets    0
# venue             0
# dtype: int64

# %%
import missingno as no
no.bar(data,figsize=(10,5), fontsize=12,color='brown')
plt.title("Null Values")
plt.show()

# %% [markdown]
# # Full summary of the dataframe

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              756 non-null    int64
#  1   season          756 non-null    int64
#  2   date            756 non-null    object
#  3   team1           756 non-null    object
#  4   team2           756 non-null    object
#  5   toss_winner     756 non-null    object
#  6   toss_decision   756 non-null    object
#  7   result          756 non-null    object
#  8   dl_applied      756 non-null    int64
#  9   win_by_runs     756 non-null    int64
#  10  win_by_wickets  756 non-null    int64
#  11  venue           756 non-null    object
# dtypes: int64(5), object(7)
# memory usage: 71.0+ KB

# %% [markdown]
# # Statistical details of the dataset

# %%
data.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %% [markdown]
# # Shape of dataset

# %%
data.shape
# Out:
# (756, 12)

# %% [markdown]
# # Find the dtypes in the Dataset

# %%
data.dtypes
# Out:
# id                 int64
# season             int64
# date              object
# team1             object
# team2             object
# toss_winner       object
# toss_decision     object
# result            object
# dl_applied         int64
# win_by_runs        int64
# win_by_wickets     int64
# venue             object
# dtype: object

# %% [markdown]
# # Finding all the column names inside the dataset

# %%
data.columns
# Out:
# Index(['id', 'season', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'win_by_runs',
#        'win_by_wickets', 'venue'],
#       dtype='object')

# %% [markdown]
# # Check the dataset for duplicate and dropping element

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Function return Series with number of distinct observations over requested axis

# %%
data.nunique()
# Out:
# id                756
# season             12
# date              546
# team1              15
# team2              15
# toss_winner        15
# toss_decision       2
# result              3
# dl_applied          2
# win_by_runs        89
# win_by_wickets     11
# venue              41
# dtype: int64

# %% [markdown]
# # Find the correlation of dataset

# %%
data.corr()
# Out:
#                       id    season  dl_applied  win_by_runs  win_by_wickets
# id              1.000000  0.668304   -0.011658    -0.039403       -0.012239
# season          0.668304  1.000000   -0.001116    -0.037529       -0.009379
# dl_applied     -0.011658 -0.001116    1.000000    -0.016349       -0.011631
# win_by_runs    -0.039403 -0.037529   -0.016349     1.000000       -0.560420
# win_by_wickets -0.012239 -0.009379   -0.011631    -0.560420        1.000000

# %% [markdown]
# # Find the covariance of dataset

# %%
data.cov()
# Out:
#                           id       season  dl_applied  win_by_runs  \
# id              1.200261e+07  7795.454305   -6.326348 -3204.058562
# season          7.795454e+03    11.335982   -0.000589    -2.965710
# dl_applied     -6.326348e+00    -0.000589    0.024533    -0.060104
# win_by_runs    -3.204059e+03    -2.965710   -0.060104   550.894600
# win_by_wickets -1.436600e+02    -0.106990   -0.006172   -44.564256
#
#                 win_by_wickets
# id                 -143.660028
# season               -0.106990
# dl_applied           -0.006172
# win_by_runs         -44.564256
# win_by_wickets       11.478291

# %% [markdown]
# # Find the Series containing counts of unique values

# %%
data.value_counts()
# Out:
# id     season  date        team1                 team2                        toss_winner                  toss_decision  result  dl_applied  win_by_runs  win_by_wickets  venue
# 1      2017    2017-04-05  Sunrisers Hyderabad   Royal Challengers Bangalore  Royal Challengers Bangalore  field          normal  0           35           0               Rajiv Gandhi International Stadium, Uppal     1
# 509    2014    2014-05-23  Kings XI Punjab       Rajasthan Royals             Rajasthan Royals             field          normal  0           16           0               Punjab Cricket Association Stadium, Mohali    1
# 500    2014    2014-05-18  Sunrisers Hyderabad   Kolkata Knight Riders        Sunrisers Hyderabad          bat            normal  0           0            7               Rajiv Gandhi International Stadium, Uppal     1
# ...

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize=(37,15))
plt.bar('team1','win_by_wickets', data=data,color='green')
plt.show()

# %%
plt.figure(figsize=(37,15))
plt.bar('team2','win_by_wickets', data=data)
plt.show()

# %% [markdown]
# # Heatmap of dataset

# %%
plt.figure(figsize=(9,7))
sns.heatmap(data.corr(),annot=True,cmap='PuBuGn')
plt.show()

# %%
plt.figure(figsize=(9,7))
sns.heatmap(data.corr(),annot=True,cmap='BuGn')
plt.show()

# %%
fig,ax=plt.subplots(ncols=2,figsize=(20,8))
resign_corr = data.corr()
mask = np.triu(np.ones_like(resign_corr, dtype=np.bool))
cat_heatmap = sns.heatmap(data.corr(), mask=mask, vmin=-1, vmax=1,annot=True,ax=ax[0],cmap='bone')
cat_heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':14}, pad=12);
heatmap = sns.heatmap(resign_corr[['win_by_runs']].sort_values(by='win_by_runs',ascending=False),vmin=-1, vmax=1, annot=True,ax=ax[1],cmap='PuBu')
heatmap.set_title('Features Correlation with win_by_runs', fontdict={'fontsize':16}, pad=16);

# %%
fig,ax=plt.subplots(ncols=2,figsize=(20,8))
resign_cov = data.cov()
mask = np.triu(np.ones_like(resign_cov, dtype=np.bool))
cat_heatmap = sns.heatmap(data.cov(), mask=mask, vmin=-1, vmax=1,annot=True,ax=ax[0],cmap='YlOrRd')
cat_heatmap.set_title('Covariance Heatmap', fontdict={'fontsize':14}, pad=12);
heatmap = sns.heatmap(resign_cov[['win_by_wickets']].sort_values(by='win_by_wickets',ascending=False),vmin=-1, vmax=1, annot=True,ax=ax[1],cmap='Wistia')
heatmap.set_title('Features Cov with win_by_wickets', fontdict={'fontsize':16}, pad=16);

# %%
sns.clustermap(data.corr(),annot=True,cmap='YlGn')

# %%
sns.clustermap(data.cov(),annot=True,cmap='YlGn')

# %%
print(data['team1'].value_counts())
plt.figure(figsize=(15,8))
sns.countplot(x=data['team1'])
plt.xticks(rotation=90)
plt.show()
# Out:
# Mumbai Indians                 101
# Kings XI Punjab                 91
# Chennai Super Kings             89
# Royal Challengers Bangalore     85
# Kolkata Knight Riders           83
# Delhi Daredevils                72
# Rajasthan Royals                67
# Sunrisers Hyderabad             63
# Deccan Chargers                 43
# Pune Warriors                   20
# Gujarat Lions                   14
# Rising Pune Supergiant           8
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Delhi Capitals                   6
# Name: team1, dtype: int64

# %%
print(data['team2'].value_counts())
plt.figure(figsize=(15,8))
sns.countplot(x=data['team2'])
plt.xticks(rotation=90)
plt.show()
# Out:
# Royal Challengers Bangalore    95
# Kolkata Knight Riders          95
# Delhi Daredevils               89
# Mumbai Indians                 86
# Kings XI Punjab                85
# Rajasthan Royals               80
# Chennai Super Kings            75
# Sunrisers Hyderabad            45
# Deccan Chargers                32
# Pune Warriors                  26
# Gujarat Lions                  16
# Delhi Capitals                 10
# Rising Pune Supergiant          8
# Rising Pune Supergiants         7
# Kochi Tuskers Kerala            7
# Name: team2, dtype: int64

# %%
plt.figure(figsize=(40,25))
sns.barplot(x=data['toss_winner'], y=data['win_by_runs'],color='red')
# Out:
# <AxesSubplot:xlabel='toss_winner', ylabel='win_by_runs'>

# %%
plt.figure(figsize=(40,25))
sns.barplot(x=data['toss_winner'], y=data['win_by_wickets'],color='red')
# Out:
# <AxesSubplot:xlabel='toss_winner', ylabel='win_by_wickets'>

# %%
data.hist(bins=50 ,figsize=(20,15))
plt.show()

# %% [markdown]
# # Distribution Plot

# %%
print(data['win_by_runs'].describe())
plt.figure(figsize = (9 , 8))
sns.distplot(x = data['win_by_runs'], bins = 10)win_by_wickets
# Out:
# count    756.000000
# mean      13.283069
# std       23.471144
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       19.000000
# max      146.000000
# Name: win_by_runs, dtype: float64
# C:\Users\elcot\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
print(data['win_by_wickets'].describe())
plt.figure(figsize = (9 , 8))
sns.distplot(x = data['win_by_wickets'], bins = 10)
# Out:
# count    756.000000
# mean       3.350529
# std        3.387963
# min        0.000000
# 25%        0.000000
# 50%        4.000000
# 75%        6.000000
# max       10.000000
# Name: win_by_wickets, dtype: float64
# C:\Users\elcot\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # Stripplot

# %%
sns.stripplot(data=data, y='win_by_runs',x='toss_decision', palette='deep')
plt.title("field and bat")
plt.show()

# %% [markdown]
# # Pie Chart

# %%
label = data['team1'].unique()
label
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
plt.pie(x=data['team1'].value_counts(),labels = label,rotatelabels=False,autopct='%1.1f%%',radius=3)
plt.show()

# %%
label = data['team2'].unique()
label
# Out:
# array(['Royal Challengers Bangalore', 'Rising Pune Supergiant',
#        'Kolkata Knight Riders', 'Kings XI Punjab', 'Delhi Daredevils',
#        'Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rajasthan Royals', 'Chennai Super Kings', 'Deccan Chargers',
#        'Pune Warriors', 'Kochi Tuskers Kerala', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
plt.pie(x=data['team2'].value_counts(),labels = label,rotatelabels=False,autopct='%1.1f%%',radius=3)
plt.show()

# %% [markdown]
# # Bar Plot

# %%
x=data['toss_winner'].value_counts()
x.plot.bar()
plt.title('toss_winner')
plt.show()

# %%
x=data['toss_decision'].value_counts()
x.plot.bar()
plt.title('toss_decision')
plt.show()

# %% [markdown]
# # Count plot

# %%
print(data['team1'].value_counts())
plt.figure(figsize=(12,6))
sns.countplot(x=data['team1'])
plt.xticks(rotation=90)
plt.show()
# Out:
# Mumbai Indians                 101
# Kings XI Punjab                 91
# Chennai Super Kings             89
# Royal Challengers Bangalore     85
# Kolkata Knight Riders           83
# Delhi Daredevils                72
# Rajasthan Royals                67
# Sunrisers Hyderabad             63
# Deccan Chargers                 43
# Pune Warriors                   20
# Gujarat Lions                   14
# Rising Pune Supergiant           8
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Delhi Capitals                   6
# Name: team1, dtype: int64

# %%
print(data['team2'].value_counts())
plt.figure(figsize=(12,6))
sns.countplot(x=data['team1'])
plt.xticks(rotation=90)
plt.show()
# Out:
# Royal Challengers Bangalore    95
# Kolkata Knight Riders          95
# Delhi Daredevils               89
# Mumbai Indians                 86
# Kings XI Punjab                85
# Rajasthan Royals               80
# Chennai Super Kings            75
# Sunrisers Hyderabad            45
# Deccan Chargers                32
# Pune Warriors                  26
# Gujarat Lions                  16
# Delhi Capitals                 10
# Rising Pune Supergiant          8
# Rising Pune Supergiants         7
# Kochi Tuskers Kerala            7
# Name: team2, dtype: int64

# %%
sns.countplot(x=data['toss_decision'])
# Out:
# <AxesSubplot:xlabel='toss_decision', ylabel='count'>

# %% [markdown]
# # Pairplot

# %%
figsize=(15,10)
sns.pairplot(data,hue='toss_decision',palette='dark',markers=["o", "s"])
